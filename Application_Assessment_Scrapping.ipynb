# %%
pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.2 MB/s eta 0:00:00
# ...

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
# Menyimpan ulasan dalam file CSV
import csv
import pandas as pd  # Pandas untuk manipulasi dan analisis data

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews(
    'com.gojek.app',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=15000        # Jumlah maksimum ulasan yang ingin diambil
)

# %%
scrapreview
# Out:
# ([{'reviewId': 'fcecd263-6061-4de6-b9f7-ecc2608922dc',
#    'userName': 'Pengguna Google',
#    'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#    'content': 'Aplikasi sudah sangat baik, tapi saya kecewa, harusnya pihak gojek punya data riwayat transaksi, dan kelihatan apakah pengguna ada indikasi kesengajaan tidak membayar tagihan atau hanya lupa, dan kenapa WA untuk menagih tidak ke nomor pengguna dahulu tetapi malah ke orang terdekat dan dengan penggunaan bahasa yang kurang enak. Apakah tidah ada pelatihan dahulu untuk tim yang bertugas menagih.. Selama belum ditinjau penilaian tidak akan diganti!!',
#    'score': 1,
#    'thumbsUpCount': 101,
#    'reviewCreatedVersion': '4.90.2',
#    'at': datetime.datetime(2024, 7, 11, 4, 37, 32),
# ...

# %%
with open('gojek_assessment.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
app_reviews_df = pd.DataFrame(scrapreview[0])
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('gojek_assessment.csv', index=False)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
jumlah_ulasan
# Out:
# 15000

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  fcecd263-6061-4de6-b9f7-ecc2608922dc  Pengguna Google
# 1  ad5d42d7-26b3-4b05-84d5-ec7a1630195c  Pengguna Google
# 2  ea5d6709-10e5-4b47-9559-eb86a31208e5  Pengguna Google
# 3  1bf37a40-af8c-4d1f-a677-07a46b121241  Pengguna Google
# 4  3e851be3-0abe-4a29-84f3-9f2d6d7553a2  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi sudah sangat baik, tapi saya kecewa, ...      1            101
# 1  Opsi pemilihan GOFOOD "terdekat" sekarang kura...      2            180
# ...

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              15000 non-null  object
#  1   userName              15000 non-null  object
#  2   userImage             15000 non-null  object
#  3   content               14999 non-null  object
#  4   score                 15000 non-null  int64
#  5   thumbsUpCount         15000 non-null  int64
#  6   reviewCreatedVersion  12917 non-null  object
#  7   at                    15000 non-null  datetime64[ns]
#  8   replyContent          7345 non-null   object
#  9   repliedAt             7345 non-null   datetime64[ns]
#  10  appVersion            12917 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.3+ MB
